# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib notebook

# %%
Ciudades = [
    ['Londres', 51.5, -0.1167],
    ['Bogotá', 4.5964, -74.0833],
    ['Roma', 41.8960, 12.4833],
    ['Melbourne', -37.8200, 144.9750],
    ['Nairobi', -1.2833, 36.8167],
    ['Santiago', -33.4500, -70.6670],
    ['Nueva York', 40.6943, -73.9249],
    ['Los Angeles', 34.1139, -118.4068],
    ['Moscú', 55.7522, 37.6155],
    ['Quito', -0.2150, -78.5001],
    ['Tokio', 35.6850, 139.7514],
    ['Lagos', 6.4433, 3.3915],
    ['Atenas', 37.9833, 23.7333],
    ['Belén de Pará', -1.4500, -48.4800],
    ['Budapest', 47.5000, 19.0833],
    ['Vancouver', 49.2734, -123.1216],
    ['París', 48.8667, 2.3333],
    ['Puebla', 19.0500, -98.2000],
    ['Cali', 3.4372201, -76.5224991],
    ['Bucaramanga', 7.1253901, -73.1197968],
    ['Madrid', -3.7025600, 40.4165000],
    ['Chicago', 41.881832, -87.623177],
    ['Fulton', 38.846668, -91.948059],
    ['Sparks', 39.554443, -119.735558],
    ['Venecia', 45.438759, 12.327145],
    ['Siena', 43.318611, 11.330556],
    ['Sao Paulo', -23.5587, -46.6250],
    ['Mumbai', 19.0170, 72.8570],
    ['Oaxaca', 17.054230, -96.713226]
]


def GradToRad(grados):
    radianes = (math.pi * grados) / 180
    return radianes

def Geo(geografico):
    pendiente = (0-180)/(90-(-90))
    ecu = (pendiente * geografico)+90
    return ecu
    

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

phi, theta = np.mgrid[0 : 2 * np.pi : 0.1, 0 : np.pi : 0.1]  # Equivale a hacer un doble for

# Para pasar de coordenadas esféricas (phi, theta) a coordenadas cartesianas (x, y, z):

x = np.cos(phi) * np.sin(theta)
y = np.sin(phi) * np.sin(theta)
z = np.cos(theta)

# Para graficar la esfera (estructura de alambre):

ax.plot_wireframe(x, y, z, color='blue', rstride=2, cstride=2, linewidth=0.5, alpha=0.8)

for i in Ciudades:
    Lat = i[1]
    Lon = i[2]
    LatMath = Geo(Lat)
    xPunto = np.cos(GradToRad(Lon))*np.sin(GradToRad(LatMath))
    yPunto = np.sin(GradToRad(Lon)) * np.sin(GradToRad(LatMath))
    zPunto = np.cos(GradToRad(LatMath))
    ax.scatter(xPunto, yPunto, zPunto, color='red', s=10)
    ax.text(xPunto, yPunto, zPunto, i[0], color='black')


# Para graficar un punto cualquiera en el espacio 3d, en este caso (2, -2, 1):

#ax.scatter(2, -2, 1, color='red', s=10) # El valor de s modifica el grosor del punto

# Para hacer una etiqueta, en este caso sobre el punto (2, -2, 1):

#ax.text(2, -2, 1, 'Bog', color='black')

# Para graficar una flecha, en este caso del origen al punto (2, -2, 1):

#ax.quiver(0, 0, 0, 2, -2, 1, color='blue')

# Nombres de los ejes

ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

phi, theta = np.mgrid[0 : 2 * np.pi : 0.1, 0 : np.pi : 0.1]  # Equivale a hacer un doble for

# Para pasar de coordenadas esféricas (phi, theta) a coordenadas cartesianas (x, y, z):

x = np.cos(phi) * np.sin(theta)
y = np.sin(phi) * np.sin(theta)
z = np.cos(theta)

ax.plot_wireframe(x, y, z, color='blue', rstride=2, cstride=2, linewidth=0.5, alpha=0.8)

# Creamos el vector de colores 
colores =['CYAN','orange','indigo','blue','green','MAGENTA']

datos =[["0",0.0,0.0],
       ["1",90.0,0.0],
       ["in",45.00000000000001,90.0],
       ["out",45.00000000000001,-90.0],
       ["+",45.00000000000001,0.0],
       ["-",45.00000000000001,180.0]]

#realizamos los calculos con math.radians y asi creamos los vectores, nos movemos en el rango de la matriz de datos

for i in range (len(datos)):
    phi, theta = math.radians(datos[i][2]), math.radians(datos[i][1])*2
    xPunto = np.cos(phi)*np.sin(theta)
    yPunto = np.sin(phi) * np.sin(theta)
    zPunto = np.cos(theta)
    ax.scatter(xPunto, yPunto, zPunto, color='black', s=10)
    ax.text(xPunto, yPunto, zPunto,datos[i][0] , color='red')
    ax.quiver(0, 0, 0, xPunto, yPunto, zPunto, color= colores[i])
    
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib notebook


fig = plt.figure()
aux1 = fig.add_subplot(121, projection='3d')
phi1, theta1 = np.mgrid[0 : 2 * np.pi : 0.1, 0 : np.pi : 0.1] 
aux2 = fig.add_subplot(122, projection='3d')
phi2, theta2 = np.mgrid[0 : 2 * np.pi : 0.1, 0 : np.pi : 0.1] 


# Para pasar de coordenadas esféricas (phi, theta) a coordenadas cartesianas (x, y, z):

x1 = np.cos(phi1) * np.sin(theta1)
y1 = np.sin(phi1) * np.sin(theta1)
z1 = np.cos(theta1)

x2 = np.cos(phi2) * np.sin(theta2)
y2 = np.sin(phi2) * np.sin(theta2)
z2 = np.cos(theta2)

# Para graficar la esfera (estructura de alambre):
ax1.plot_wireframe(x1, y1, z1, color='blue', rstride=2, cstride=2, linewidth=0.5, alpha=0.8)
ax2.plot_wireframe(x2, y2, z2, color='blue', rstride=2, cstride=2, linewidth=0.5, alpha=0.8)

colores =['indigo','green','CYAN','MAGENTA','orange','blue']
